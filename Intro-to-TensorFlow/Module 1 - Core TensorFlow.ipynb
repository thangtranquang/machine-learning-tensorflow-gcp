# %% [markdown]
# # Module 1: Core TensorFlow
# 1. What is TensorFlow
# 2. TensorFlow API Hierarchy
# 3. Graph and Session
# 4. Tensor and Variable
# 5. Lab: Writing low-level TensorFlow programs
# 6. Debugging TensorFlow programs
# 7. Quiz - Core TensorFlow

# %% [markdown]
# ## 1. What is TensorFlow
# ![ ](img/1-1-01.png)
# ![ ](img/1-1-02.gif)
# ![ ](img/1-1-03.png)
# ![ ](img/1-1-04.png)
# ### Benefits of a Directed Graph
# ![ ](img/1-1-05.png)
# ![ ](img/1-1-06.png)
# ![ ](img/1-1-07.png)
# ![ ](img/1-1-08.png)
# ### Quiz
#
# #### Question 1
# TensorFlow is a software framework for:
# - (x) Numeric processing
# - ( ) Neural networks only

# %% [markdown]
# ## 2. TensorFlow API Hierarchy
# ### TensorFlow toolkit hierarchy
# ![ ](img/1-2-01.png)
# ![ ](img/1-2-02.png)
# ![ ](img/1-2-03.png)
# ### Quiz
# #### Importance of an API hierarchy
# Which level of the TensorFlow API hierarchy will you tend to work at? Why is it important that the other levels are exposed by the framework?

# %% [markdown]
# ## 3. Graph and Session
# ### Graph and Session
# ![ ](img/1-3-01.png)
# ![ ](img/1-3-02.png)
# ![ ](img/1-3-03.png)
# ### Evaluating a Tensor
# ![ ](img/1-3-04.png)
# ![ ](img/1-3-05.png)
# ![ ](img/1-3-06.png)
# ![ ](img/1-3-07.png)
# ### Visualizing a graph
# ![ ](img/1-3-08.png)
# ![ ](img/1-3-09.png)
# ![ ](img/1-3-10.png)
# ![ ](img/1-3-11.png)
# ![ ](img/1-3-12.png)
# ![ ](img/1-3-13.png)
# ![ ](img/1-3-14.png)
#
# ### Quiz: Graphs and Sessions
# #### Question 1
# Which of these provides a way to visualize your TensorFlow program as a graph?
# - (x) TensorBoard
# - ( ) emacs
# - ( ) vim
#
# #### Question 2
# Which of these is a valid way to evaluate a tensor "z"? Assume you have a session named "sess" and it is the default session.
# - (x) sess.run(z)
# - (x) z.eval()
# - (x) sess.run([z])
#
# #### Question 3
# The mode to evaluate tensors immediately (instead of lazy evaluation) is called:
# - ( ) This is the default TensorFlow behavior, so there is no special name for it.
# - ( ) Interactive mode
# - (x) Eager mode
#
# #### Question 4
# TensorFlow programs are directed graphs. What are some of the benefits?
# - (x) TensorFlow can optimize the graph by merging successive nodes where necessary
# - (x) TensorFlow can insert send and receive nodes to distribute the graph across machines
# - ( ) You can write TensorFlow programs using a what-you-see-is-what-you-get (WYSIWYG) user interface

# %% [markdown]
# ## 4. Tensor and Variable
# ### Tensor
# ![ ](img/1-4-01.png)
# ![ ](img/1-4-02.png)
# ![ ](img/1-4-03.png)
#
# ### Variables
# ![ ](img/1-4-04.png)
# ![ ](img/1-4-05.png)
# ![ ](img/1-4-06.png)
# ![ ](img/1-4-07.png)

# %% [markdown]
# ## 5. Lab: Writing low-level TensorFlow programs
# Qwiklabs – Writing low-level TensorFlow programs
# This lab is part of a lab series, where you go from exploring a taxicab dataset to training and deploying a high-accuracy distributed model with Cloud ML Engine.
#
# ### What you learn
# In this lab, you will learn how the TensorFlow Python API works:
#
# - Building a graph
# - Running a graph
# - Feeding values into a graph
# - Find area of a triangle using TensorFlow
# ### Launch Cloud Datalab
# To launch Cloud Datalab:
#
# - Step 1
# Open Cloud Shell. The cloud shell icon is at the top right of the Google Cloud Platform web console:
#
# - Step 2
# In Cloud Shell, type:
#
# `gcloud compute zones list`<br>
# Note: Please pick a zone in a geographically close region from the following: us-east1, us-central1, asia-east1, europe-west1. These are the regions that currently support Cloud ML Engine jobs. Please verify here since this list may have changed after this lab was last updated. For example, if you are in the US, you may choose us-east1-c as your zone.
#
# - Step 3
# In Cloud Shell, type:
#
# `datalab create mydatalabvm --zone <ZONE>`<br>
# Replace <ZONE> with a zone name you picked from the previous step.
#
# Note: follow the prompts during this process.
#
# Datalab will take about 5 minutes to start.
#
# - Step 4
# Look back at Cloud Shell, and follow any prompts. If asked for a ssh passphrase, just hit return (for no passphrase).
#
# - Step 5
# If necessary, wait for Datalab to finish launching. Datalab is ready when you see a message prompting you to do a "Web Preview".
#
# - Step 6
# Click on the Web Preview icon on the top-right corner of the Cloud Shell ribbon. Switch or enter the port 8081.
# ![ ](img/lab-1-4-01.png)
# ![ ](img/lab-1-4-02.png)
#
# Note: If the cloud shell used for running the datalab command is closed or interrupted, the connection to your Cloud Datalab VM will terminate. If that happens, you may be able to reconnect using the command ‘datalab connect mydatalabvm' in your new Cloud Shell.
#
# ### Clone course repo within your Datalab instance
# To clone the course repo in your datalab instance:
#
# - Step 1
# In Cloud Datalab home page (browser), navigate into "notebooks" and add a new notebook using the icon  on the top left.
#
# - Step 2
# Rename this notebook as ‘repocheckout'.
#
# - Step 3
# In the new notebook, enter the following commands in the cell, and click on Run (on the top navigation bar) to run the commands:<br>
#
# `%bash
# git clone https://github.com/GoogleCloudPlatform/training-data-analyst
# rm -rf training-data-analyst/.git`
#
#
# - Step 4
# Confirm that you have cloned the repo by going back to Datalab browser, and ensure you see the training-data-analyst directory. All the files for all labs throughout this course are available in this directory.
#
#
#
# ### Getting Started with TensorFlow
# Duration is 15 min
#
# - Step 1
# In Cloud Datalab, click on the Home icon, and then navigate to notebooks/training-data-analyst > courses > machine_learning > deepdive > 03_tensorflow and open a_tfstart.ipynb
#
# Note: If the cloud shell used for running the datalab command is closed or interrupted, the connection to your Cloud Datalab VM will terminate. If that happens, you may be able to reconnect using the command **‘datalab connect mydatalabvm'** in your new Cloud Shell. Once connected, try the above step again.
#
# - Step 2
# In Datalab, click on Clear | All Cells. Now read the narrative and execute each cell in turn.

# %% [markdown]
# ## 6. Debugging TensorFlow programs
# ![ ](img/1-6-01.png)
# ![ ](img/1-6-02.png)
# ![ ](img/1-6-03.png)
# ![ ](img/1-6-04.png)
# ![ ](img/1-6-05.png)
# ![ ](img/1-6-06.png)
# ![ ](img/1-6-07.png)
# ![ ](img/1-6-08.png)
# ![ ](img/1-6-09.png)
# ![ ](img/1-6-10.png)
# ![ ](img/1-6-11.png)
# ![ ](img/1-6-12.png)
# ![ ](img/1-6-13.png)
# ![ ](img/1-6-14.png)
# ![ ](img/1-6-15.png)
# ![ ](img/1-6-16.png)
# ![ ](img/1-6-17.png)
# ![ ](img/1-6-18.png)
# ![ ](img/1-6-19.png)
# ![ ](img/1-6-20.png)
# ![ ](img/1-6-21.png)
# ![ ](img/1-6-22.png)
# ![ ](img/1-6-23.png)
# ![ ](img/1-6-24.png)
# ![ ](img/1-6-25.png)
# ![ ](img/1-6-26.png)
# ![ ](img/1-6-27.png)
# ![ ](img/1-6-28.png)
# ![ ](img/1-6-29.png)
# ![ ](img/1-6-30.png)

# %% [markdown]
# ## 7. Quiz - Core TensorFlow
# ### Question 1
# What is TensorFlow? (choose all that apply)
# - [x] TensorFlow is an open-source high-performance library for numerical computation that uses directed graphs
# - [x] TensorFlow is open source
# - [ ] TensorFlow is used exclusively to build Machine Learning models
#
# ### Question 2
# True or False: When you run a TensorFlow graph (like a + b), you immediately get the output of the graph (the sum of a and b)
# - (x) True - but only if you have tf.eager mode enabled
# - ( ) False - TensorFlow always builds the graph but does not execute it
#
# ### Question 3
# What do nodes in a TensorFlow graph represent?
# - ( ) All of the above
# - (x) Mathematical operations
# - ( ) Arrays of data
# - ( ) Machine Learning
#
# ### Question 4
# What is a tensor?
# - ( ) A hyperparameter set before model training
# - (x) A n-dimensional array of data (generalization of a vector)
# - ( ) A different machine learning model type
#
# ### Question 5
# True or False: You can only run TensorFlow on Google Cloud
# - ( ) True
# - (x) False
#
# ### Question 6
# The iterative process where a TensorFlow model can crowdsource and combine model feedback from individual users is called what?
# - ( ) Distributed learning
# - ( ) TensorFlow learning
# - (x) Federated learning
#
# ### Question 7
# What is the high level API that allows for distributed training in TensorFlow?
# - (x) tf.estimator
# - ( ) tf.losses
# - ( ) tf.dist_train
# - ( ) tf.evaluate
#
# ### Question 8
# How do you run a TensorFlow graph?
# - (x) Call run() on a tf.Session
# - ( ) Call execute() on a tf.Session
# - ( ) TensorFlow graphs are ran automatically
#
# ### Question 9
# Why would you call tf.summary.FileWriter?
# - ( ) To write out the trained ML model output into a file for distribution
# - ( ) To output the graph in a human-readable format for sharing
# - (x) To output statistics and visualize them in a tool like TensorBoard
#
# ### Question 10
# What is the shape of tf.constant([2, 3, 5])?
# - ( ) It's a vector so it would be (1,3)
# - (x) It's a vector so it would be (3)
# - ( ) It's a scalar so it would be ( )
# - ( ) It's a scalar so it would be (3)
